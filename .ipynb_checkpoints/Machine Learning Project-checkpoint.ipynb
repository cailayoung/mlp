# %%
# linear algebra
import numpy as np 

# data processing
import pandas as pd 

# data visualization
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style

# Algorithms
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB

# %%
#using survivor demographics to predict survival of the titanic

# %%
train_df= pd.read_csv("/Users/cailayoung/Downloads/zips/titanic/train.csv")
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#descriptive statistics on full dataset
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#cleaning data, getting rid of anything unrelated to demographics
train_df=train_df.drop(["Name", "Embarked", "PassengerId",
                "SibSp", "Parch", "Ticket", "Fare", "Cabin"], axis=1)
train_df
# Out:
#      Survived  Pclass     Sex   Age
# 0           0       3    male  22.0
# 1           1       1  female  38.0
# 2           1       3  female  26.0
# 3           1       1  female  35.0
# 4           0       3    male  35.0
# ..        ...     ...     ...   ...
# 886         0       2    male  27.0
# 887         1       1  female  19.0
# 888         0       3  female   NaN
# 889         1       1    male  26.0
# 890         0       3    male  32.0
#
# [891 rows x 4 columns]

# %%
#checking to see if there is null data in filtered set
null = train_df.isnull()
null.value_counts()
# Out:
# Survived  Pclass  Sex    Age
# False     False   False  False    714
#                          True     177
# dtype: int64

# %%
#getting rid of null values
train_df.dropna()
# Out:
#      Survived  Pclass     Sex   Age
# 0           0       3    male  22.0
# 1           1       1  female  38.0
# 2           1       3  female  26.0
# 3           1       1  female  35.0
# 4           0       3    male  35.0
# ..        ...     ...     ...   ...
# 885         0       3  female  39.0
# 886         0       2    male  27.0
# 887         1       1  female  19.0
# 889         1       1    male  26.0
# 890         0       3    male  32.0
#
# [714 rows x 4 columns]

# %%
#descriptive data of survivors
survived = train_df[train_df["Survived"]>0] 
survived
# Out:
#      Survived  Pclass     Sex   Age
# 1           1       1  female  38.0
# 2           1       3  female  26.0
# 3           1       1  female  35.0
# 8           1       3  female  27.0
# 9           1       2  female  14.0
# ..        ...     ...     ...   ...
# 875         1       3  female  15.0
# 879         1       1  female  56.0
# 880         1       2  female  25.0
# 887         1       1  female  19.0
# 889         1       1    male  26.0
#
# [342 rows x 4 columns]

# %%
survived.describe()

# %%
#descriptive data of deaths
died = train_df[train_df["Survived"]==0] 
died
# Out:
#      Survived  Pclass     Sex   Age
# 0           0       3    male  22.0
# 4           0       3    male  35.0
# 5           0       3    male   NaN
# 6           0       1    male  54.0
# 7           0       3    male   2.0
# ..        ...     ...     ...   ...
# 884         0       3    male  25.0
# 885         0       3  female  39.0
# 886         0       2    male  27.0
# 888         0       3  female   NaN
# 890         0       3    male  32.0
#
# [549 rows x 4 columns]

# %%
died.describe()
# Out:
#        Survived      Pclass         Age
# count     549.0  549.000000  424.000000
# mean        0.0    2.531876   30.626179
# std         0.0    0.735805   14.172110
# min         0.0    1.000000    1.000000
# 25%         0.0    2.000000   21.000000
# 50%         0.0    3.000000   28.000000
# 75%         0.0    3.000000   39.000000
# max         0.0    3.000000   74.000000

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 28.0+ KB

# %%
#determining correlation between variables
corr_matrix = train_df.corr(method="pearson")
sns.heatmap(corr_matrix, vmin=-1., vmax=1., annot=True, fmt='.2f', cmap="YlGnBu", cbar=True, linewidths=0.5)
plt.title("pearson correlation")
#pearson correlation s a measure of linear correlation between two sets of data. 
#It is the ratio between the covariance of two variables and the product of their standard deviations 
#it is essentially a normalized measurement of the covariance,
#the result always has a value between −1 and 1.
# Out:
# Text(0.5, 1.0, 'pearson correlation')

# %%
survivor= "survivor"
non_survivor= "non-survivor"
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 4))
#creating men and women variables to graph
lwomen = survived[survived['Sex']=='female']
lmen = survived[survived['Sex']=='male']
dwomen= died[died['Sex']=='female']
dmen= died[died['Sex']=='male']
#creating histogram with women survived and dead
ax = sns.histplot(lwomen.Age, bins=18, label = survivor, ax = axes[0], kde =False)
ax = sns.histplot(dwomen.Age, bins=40, label = non_survivor, ax = axes[0], kde =False)
ax.legend()
ax.set_title('Female')
#creating histogram with men survived and dead
ax = sns.histplot(lmen.Age, bins=18, label = survivor, ax = axes[1], kde = False)
ax = sns.histplot(dmen.Age, bins=40, label = non_survivor, ax = axes[1], kde = False)
ax.legend()
_ = ax.set_title('Male')

# %%
#helps in visualizing distribution of one variable as well as the relationship 
#between multiple variables separately within subsets of your dataset using 
#multiple panels.
FacetGrid = sns.FacetGrid(train_df, height=4.5, aspect=1.6)
FacetGrid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette=None,  order=None, hue_order=None )
FacetGrid.add_legend()

# %%
#simple bar graph comparing pclass and survival
#(wanted to see the specific impact of class on survival)
sns.barplot(x='Pclass', y='Survived', data=train_df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
#facet grid compared multiple variables separately and then
#mapped into a histogram for visualization, using age this time
grid = sns.FacetGrid(train_df, col='Survived', row='Pclass', height=2.2, aspect=1.6)
grid.map(plt.hist, 'Age', alpha=.5, bins=20)
grid.add_legend();

# %%
test_df= pd.read_csv("/Users/cailayoung/Downloads/zips/titanic/test.csv")
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test_df=test_df.drop(["Name", "Embarked", "PassengerId",
                "SibSp", "Parch", "Ticket", "Fare", "Cabin"], axis=1)
test_df
# Out:
#      Pclass     Sex   Age
# 0         3    male  34.5
# 1         3  female  47.0
# 2         2    male  62.0
# 3         3    male  27.0
# 4         3  female  22.0
# ..      ...     ...   ...
# 413       3    male   NaN
# 414       1  female  39.0
# 415       3    male  38.5
# 416       3    male   NaN
# 417       3    male   NaN
#
# [418 rows x 3 columns]

# %%
data = [train_df, test_df]

for dataset in data:
    mean = train_df["Age"].mean()
    std = test_df["Age"].std()
    is_null = dataset["Age"].isnull().sum()
    # compute random numbers between the mean, std to and is_null
    rand_age = np.random.randint(mean - std, mean + std, size = is_null)
    # fill NaN values in Age column with random values generated
    age_slice = dataset["Age"].copy()
    age_slice[np.isnan(age_slice)] = rand_age
    dataset["Age"] = age_slice
    #changing from float to integer
    dataset["Age"] = train_df["Age"].astype(int)
    #covert 'sex' into numeric data
    genders = {"male": 0, "female": 1}
    
data = [train_df, test_df]

for dataset in data:
    dataset['Sex'] = dataset['Sex'].map(genders)
    #have to put ages into groups and make them integers to make them workable
data = [train_df, test_df]
for dataset in data:
    dataset['Age'] = dataset['Age'].astype(int)
    dataset.loc[ dataset['Age'] <= 11, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 11) & (dataset['Age'] <= 18), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 18) & (dataset['Age'] <= 22), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 22) & (dataset['Age'] <= 27), 'Age'] = 3
    dataset.loc[(dataset['Age'] > 27) & (dataset['Age'] <= 33), 'Age'] = 4
    dataset.loc[(dataset['Age'] > 33) & (dataset['Age'] <= 40), 'Age'] = 5
    dataset.loc[(dataset['Age'] > 40) & (dataset['Age'] <= 66), 'Age'] = 6
    dataset.loc[ dataset['Age'] > 66, 'Age'] = 6

# %%
#defining training data and test data
X_train = train_df.drop("Survived", axis=1)
Y_train = train_df["Survived"]
X_test  = test_df.copy()

# %%
#starting with log reg bc it is simple and quick
#used to predict the probability of a categorical dependent variable.
#here I want to predict survival based on Age, Sex, and Pclass.
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)

Y_pred = logreg.predict(X_test)

acc_log = round(logreg.score(X_train, Y_train) * 100, 2)
acc_log
# Out:
# 79.46

# %%
#tried this next bc it performs better with large sample
#attempts to find a hyperplane to maximize the distance 
#between classified samples.
linear_svc = LinearSVC()
linear_svc.fit(X_train, Y_train)

Y_pred = linear_svc.predict(X_test)

acc_linear_svc = round(linear_svc.score(X_train, Y_train) * 100, 2)
acc_linear_svc
# Out:
# /Users/cailayoung/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 78.9

# %%
#Random forest builds multiple decision trees and merges them
#together to get a more accurate and stable prediction
#supervised learning algorithm
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, Y_train)

Y_prediction = random_forest.predict(X_test)

random_forest.score(X_train, Y_train)
acc_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)
acc_random_forest
#most accurate of the 3
# Out:
# 81.82

# %%
from sklearn.model_selection import cross_val_score
rf = RandomForestClassifier(n_estimators=100)
scores = cross_val_score(rf, X_train, Y_train, cv=10, scoring = "accuracy")
print("Scores:", scores)
print("Mean:", scores.mean())
print("Standard Deviation:", scores.std())
#this is K-Fold Cross Validation, train data was used to test the models
#needs to be cross-validated with test data
#avg accuracy= 78%
#std. dev.= 2%
# Out:
# Scores: [0.78888889 0.75280899 0.75280899 0.83146067 0.80898876 0.76404494
#  0.7752809  0.7752809  0.7752809  0.78651685]
# Mean: 0.7811360799001249
# Standard Deviation: 0.02323187493305733

# %%
importances = pd.DataFrame({'feature':X_train.columns,'importance':np.round(random_forest.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False).set_index('feature')
importances
#measures relative importance of each of each feature
#sum of all is equal to 1
# Out:
#          importance
# feature
# Sex           0.586
# Pclass        0.253
# Age           0.161

# %%
importances.plot.bar()
# Out:
# <AxesSubplot:xlabel='feature'>

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
predictions = cross_val_predict(random_forest, X_train, Y_train, cv=3)
confusion_matrix(Y_train, predictions)
#497 passengers were correctly classified as not survived(true negatives)
#52 passengers were wrongly classified as not survived(false positives)
#131 passengers were wrongly classified as survived(false negatives)
#211 passengers were correctly classified as survived (true positives)
# Out:
# array([[497,  52],
#        [131, 211]])

# %%
#visual confusion matrix
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics
confusion_matrix = metrics.confusion_matrix(Y_train, predictions)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %%
#precision and recall
from sklearn.metrics import precision_score, recall_score

print("Precision:", precision_score(Y_train, predictions))
#model predicts a passengers survival correctly 80% of the time
print("Recall:",recall_score(Y_train, predictions))
#model predicted the survival of 62% of the actual survivors
# Out:
# Precision: 0.8022813688212928
# Recall: 0.6169590643274854

# %%
#an f-score combines precision and recall into one score
from sklearn.metrics import f1_score

f1_score(Y_train, predictions)
# Out:
# 0.6975206611570248
